# %%
# !wget -r -N -c -np https://physionet.org/files/ludb/1.0.0/
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Length: 116 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/67.atr_v4’
#
# physionet.org/files 100%[===================>]     116  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (30.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/67.atr_v4’ saved [116/116]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/67.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 116 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/67.atr_v5’
#
# physionet.org/files 100%[===================>]     116  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (28.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/67.atr_v5’ saved [116/116]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/67.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 110 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/67.atr_v6’
#
# physionet.org/files 100%[===================>]     110  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (31.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/67.atr_v6’ saved [110/110]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/67.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/67.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.02s
#
# 2020-12-08 06:40:02 (4.80 MB/s) - ‘physionet.org/files/ludb/1.0.0/67.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/67.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 771 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/67.hea’
#
# physionet.org/files 100%[===================>]     771  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (199 MB/s) - ‘physionet.org/files/ludb/1.0.0/67.hea’ saved [771/771]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_avf’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (40.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_avf’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_avl’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (39.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_avl’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_avr’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (40.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_avr’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_i’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (38.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_i’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_ii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_ii’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (31.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_ii’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_iii’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (37.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_iii’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_v1’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (37.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_v1’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_v2’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (38.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_v2’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_v3’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (40.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_v3’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_v4’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (40.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_v4’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_v5’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (45.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_v5’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.atr_v6’
#
# physionet.org/files 100%[===================>]     152  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (39.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.atr_v6’ saved [152/152]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.001s
#
# 2020-12-08 06:40:02 (163 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/68.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 834 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/68.hea’
#
# physionet.org/files 100%[===================>]     834  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (32.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/68.hea’ saved [834/834]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_avf’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (16.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_avf’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_avl’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (49.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_avl’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_avr’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (46.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_avr’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_i’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (50.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_i’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_ii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_ii’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (46.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_ii’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_iii’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (45.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_iii’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_v1’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (49.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_v1’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_v2’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (48.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_v2’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_v3’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (49.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_v3’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_v4’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:02 (46.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_v4’ saved [188/188]
#
# --2020-12-08 06:40:02--  https://physionet.org/files/ludb/1.0.0/69.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_v5’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (49.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_v5’ saved [188/188]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/69.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.atr_v6’
#
# physionet.org/files 100%[===================>]     188  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (46.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.atr_v6’ saved [188/188]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/69.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.001s
#
# 2020-12-08 06:40:03 (89.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/69.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 897 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/69.hea’
#
# physionet.org/files 100%[===================>]     897  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (204 MB/s) - ‘physionet.org/files/ludb/1.0.0/69.hea’ saved [897/897]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_avf’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (30.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_avf’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_avl’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (33.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_avl’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_avr’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (33.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_avr’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_i’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (29.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_i’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_ii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_ii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (31.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_ii’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_iii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (40.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_iii’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 124 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_v1’
#
# physionet.org/files 100%[===================>]     124  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (32.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_v1’ saved [124/124]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 128 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_v2’
#
# physionet.org/files 100%[===================>]     128  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (33.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_v2’ saved [128/128]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 130 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_v3’
#
# physionet.org/files 100%[===================>]     130  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (31.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_v3’ saved [130/130]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_v4’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (35.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_v4’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_v5’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (38.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_v5’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.atr_v6’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (33.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.atr_v6’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.001s
#
# 2020-12-08 06:40:03 (136 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/7.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 960 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/7.hea’
#
# physionet.org/files 100%[===================>]     960  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (223 MB/s) - ‘physionet.org/files/ludb/1.0.0/7.hea’ saved [960/960]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_avf’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (54.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_avf’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_avl’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (54.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_avl’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_avr’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (56.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_avr’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_i’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (52.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_i’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_ii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_ii’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (47.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_ii’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_iii’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (62.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_iii’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_v1’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (34.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_v1’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_v2’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (57.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_v2’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 218 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_v3’
#
# physionet.org/files 100%[===================>]     218  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (47.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_v3’ saved [218/218]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_v4’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (59.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_v4’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_v5’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (51.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_v5’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.atr_v6’
#
# physionet.org/files 100%[===================>]     224  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (53.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.atr_v6’ saved [224/224]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.001s
#
# 2020-12-08 06:40:03 (157 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/70.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 768 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/70.hea’
#
# physionet.org/files 100%[===================>]     768  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (180 MB/s) - ‘physionet.org/files/ludb/1.0.0/70.hea’ saved [768/768]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/71.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_avf’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (34.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_avf’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/71.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_avl’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:03 (32.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_avl’ saved [134/134]
#
# --2020-12-08 06:40:03--  https://physionet.org/files/ludb/1.0.0/71.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_avr’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (30.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_avr’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_i’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (29.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_i’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.atr_ii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_ii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (28.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_ii’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_iii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (33.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_iii’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_v1’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (35.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_v1’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_v2’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (5.77 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_v2’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_v3’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (33.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_v3’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_v4’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (34.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_v4’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_v5’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (31.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_v5’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.atr_v6’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (31.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.atr_v6’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.001s
#
# 2020-12-08 06:40:04 (129 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/71.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 819 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/71.hea’
#
# physionet.org/files 100%[===================>]     819  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (204 MB/s) - ‘physionet.org/files/ludb/1.0.0/71.hea’ saved [819/819]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_avf’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (30.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_avf’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_avl’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (32.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_avl’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_avr’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (26.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_avr’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_i’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (34.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_i’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_ii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_ii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (36.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_ii’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_iii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (36.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_iii’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_v1’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (35.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_v1’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_v2’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (37.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_v2’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_v3’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (33.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_v3’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_v4’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (25.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_v4’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_v5’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (23.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_v5’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.atr_v6’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (36.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.atr_v6’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.001s
#
# 2020-12-08 06:40:04 (142 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/72.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 780 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/72.hea’
#
# physionet.org/files 100%[===================>]     780  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (196 MB/s) - ‘physionet.org/files/ludb/1.0.0/72.hea’ saved [780/780]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/73.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_avf’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (34.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_avf’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/73.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_avl’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (26.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_avl’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/73.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_avr’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (34.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_avr’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/73.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_i’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (26.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_i’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/73.atr_ii
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_ii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:04 (30.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_ii’ saved [134/134]
#
# --2020-12-08 06:40:04--  https://physionet.org/files/ludb/1.0.0/73.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_iii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (35.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_iii’ saved [134/134]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/73.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_v1’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (30.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_v1’ saved [134/134]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/73.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_v2’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (37.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_v2’ saved [134/134]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/73.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_v3’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (38.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_v3’ saved [134/134]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/73.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_v4’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (36.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_v4’ saved [134/134]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/73.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_v5’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (28.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_v5’ saved [134/134]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/73.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.atr_v6’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (33.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.atr_v6’ saved [134/134]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/73.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.02s
#
# 2020-12-08 06:40:05 (4.73 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/73.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 945 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/73.hea’
#
# physionet.org/files 100%[===================>]     945  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (212 MB/s) - ‘physionet.org/files/ludb/1.0.0/73.hea’ saved [945/945]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_avf’
#
# physionet.org/files 100%[===================>]     104  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (26.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/74.atr_avf’ saved [104/104]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_avl’
#
# physionet.org/files 100%[===================>]     104  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (30.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/74.atr_avl’ saved [104/104]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_avr’
#
# physionet.org/files 100%[===================>]     104  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (27.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/74.atr_avr’ saved [104/104]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_i’
#
# physionet.org/files 100%[===================>]     104  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (28.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/74.atr_i’ saved [104/104]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_ii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_ii’
#
# physionet.org/files 100%[===================>]     104  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (26.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/74.atr_ii’ saved [104/104]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_iii’
#
# physionet.org/files 100%[===================>]     104  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (25.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/74.atr_iii’ saved [104/104]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_v1’
#
# physionet.org/files 100%[===================>]     104  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (28.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/74.atr_v1’ saved [104/104]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_v2’
#
# physionet.org/files 100%[===================>]     104  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (23.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/74.atr_v2’ saved [104/104]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_v3’
#
# physionet.org/files 100%[===================>]     104  --.-KB/s    in 0s
#
# 2020-12-08 06:40:05 (28.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/74.atr_v3’ saved [104/104]
#
# --2020-12-08 06:40:05--  https://physionet.org/files/ludb/1.0.0/74.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 104 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/74.atr_v4’
#
# ...
#
# --2020-12-08 06:40:16--  https://physionet.org/files/ludb/1.0.0/97.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/97.atr_v5’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:16 (34.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/97.atr_v5’ saved [134/134]
#
# --2020-12-08 06:40:16--  https://physionet.org/files/ludb/1.0.0/97.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/97.atr_v6’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (34.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/97.atr_v6’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/97.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/97.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.002s
#
# 2020-12-08 06:40:17 (50.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/97.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/97.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 865 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/97.hea’
#
# physionet.org/files 100%[===================>]     865  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (224 MB/s) - ‘physionet.org/files/ludb/1.0.0/97.hea’ saved [865/865]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_avf’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (37.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_avf’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_avl’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (28.1 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_avl’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_avr’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (34.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_avr’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_i’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (33.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_i’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_ii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_ii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (36.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_ii’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_iii’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (34.9 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_iii’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_v1’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (33.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_v1’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_v2’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (30.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_v2’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_v3’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (30.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_v3’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_v4’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (37.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_v4’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_v5’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (36.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_v5’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 134 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.atr_v6’
#
# physionet.org/files 100%[===================>]     134  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (32.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.atr_v6’ saved [134/134]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (283 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/98.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 802 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/98.hea’
#
# physionet.org/files 100%[===================>]     802  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (170 MB/s) - ‘physionet.org/files/ludb/1.0.0/98.hea’ saved [802/802]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_avf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_avf’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (51.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_avf’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_avl
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_avl’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (50.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_avl’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_avr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_avr’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (49.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_avr’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_i
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_i’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (48.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_i’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_ii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_ii’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (50.2 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_ii’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_iii
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_iii’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (55.6 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_iii’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_v1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_v1’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (49.0 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_v1’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_v2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_v2’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (51.7 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_v2’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_v3
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_v3’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (55.5 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_v3’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_v4
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_v4’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (51.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_v4’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_v5
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_v5’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (55.4 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_v5’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.atr_v6
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 206 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.atr_v6’
#
# physionet.org/files 100%[===================>]     206  --.-KB/s    in 0s
#
# 2020-12-08 06:40:17 (43.8 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.atr_v6’ saved [206/206]
#
# --2020-12-08 06:40:17--  https://physionet.org/files/ludb/1.0.0/99.dat
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.02s
#
# 2020-12-08 06:40:18 (4.58 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.dat’ saved [120000/120000]
#
# --2020-12-08 06:40:18--  https://physionet.org/files/ludb/1.0.0/99.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 875 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/99.hea’
#
# physionet.org/files 100%[===================>]     875  --.-KB/s    in 0s
#
# 2020-12-08 06:40:18 (229 MB/s) - ‘physionet.org/files/ludb/1.0.0/99.hea’ saved [875/875]
#
# --2020-12-08 06:40:18--  https://physionet.org/files/ludb/1.0.0/ANNOTATORS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 757 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/ANNOTATORS’
#
# physionet.org/files 100%[===================>]     757  --.-KB/s    in 0s
#
# 2020-12-08 06:40:18 (201 MB/s) - ‘physionet.org/files/ludb/1.0.0/ANNOTATORS’ saved [757/757]
#
# --2020-12-08 06:40:18--  https://physionet.org/files/ludb/1.0.0/LICENSE.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 20402 (20K) [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/LICENSE.txt’
#
# physionet.org/files 100%[===================>]  19.92K  --.-KB/s    in 0s
#
# 2020-12-08 06:40:18 (242 MB/s) - ‘physionet.org/files/ludb/1.0.0/LICENSE.txt’ saved [20402/20402]
#
# --2020-12-08 06:40:18--  https://physionet.org/files/ludb/1.0.0/README
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6452 (6.3K) [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/README’
#
# physionet.org/files 100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2020-12-08 06:40:18 (1.24 GB/s) - ‘physionet.org/files/ludb/1.0.0/README’ saved [6452/6452]
#
# --2020-12-08 06:40:18--  https://physionet.org/files/ludb/1.0.0/RECORDS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 691 [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/RECORDS’
#
# physionet.org/files 100%[===================>]     691  --.-KB/s    in 0s
#
# 2020-12-08 06:40:18 (188 MB/s) - ‘physionet.org/files/ludb/1.0.0/RECORDS’ saved [691/691]
#
# --2020-12-08 06:40:18--  https://physionet.org/files/ludb/1.0.0/SHA256SUMS.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 210986 (206K) [text/plain]
# Saving to: ‘physionet.org/files/ludb/1.0.0/SHA256SUMS.txt’
#
# physionet.org/files 100%[===================>] 206.04K  --.-KB/s    in 0.02s
#
# 2020-12-08 06:40:18 (13.3 MB/s) - ‘physionet.org/files/ludb/1.0.0/SHA256SUMS.txt’ saved [210986/210986]
#
# FINISHED --2020-12-08 06:40:18--
# Total wall clock time: 1m 29s
# Downloaded: 2807 files, 24M in 1.1s (21.7 MB/s)

# %%
# !pip install wfdb
# Out:
# Collecting wfdb
#   Downloading https://files.pythonhosted.org/packages/b1/a0/922d06ec737e219a9f45545432842e68a84e8b52f292704056eea1d35e41/wfdb-3.1.1.tar.gz (113kB)
#      |████████████████████████████████| 122kB 19.5MB/s
# Requirement already satisfied: certifi>=2016.8.2 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2020.11.8)
# Requirement already satisfied: chardet>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (3.0.4)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (0.10.0)
# Requirement already satisfied: idna>=2.2 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2.10)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from wfdb) (0.17.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.3.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (3.2.2)
# Collecting mne>=0.18.0
#   Downloading https://files.pythonhosted.org/packages/4d/0e/6448521738d3357c205795fd5846d023bd7935bb83ba93a1ba0f7124205e/mne-0.21.2-py3-none-any.whl (6.8MB)
#      |████████████████████████████████| 6.8MB 28.3MB/s
# Collecting nose>=1.3.7
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 34.4MB/s
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.18.5)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.1.4)
# Requirement already satisfied: pyparsing>=2.0.4 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.4.2 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2.8.1)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2018.9)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2.23.0)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.6/dist-packages (from wfdb) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.4.1)
# Requirement already satisfied: six>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.15.0)
# Requirement already satisfied: sklearn>=0.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (0.0)
# Collecting threadpoolctl>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied: urllib3>=1.22 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.24.3)
# Building wheels for collected packages: wfdb
#   Building wheel for wfdb (setup.py) ... done
#   Created wheel for wfdb: filename=wfdb-3.1.1-cp36-none-any.whl size=117828 sha256=325dd5b402519749b5cf8db03fa8082694f327e34c3083900c9be98ef9484fba
#   Stored in directory: /root/.cache/pip/wheels/bc/d0/c1/90538d266ccba2d1076fbc9970192c7ea1a09c99df3e65c69b
# Successfully built wfdb
# Installing collected packages: mne, nose, threadpoolctl, wfdb
# Successfully installed mne-0.21.2 nose-1.3.7 threadpoolctl-2.1.0 wfdb-3.1.1

# %%
# !pip install tensorflow==2.2.0
# Out:
# Collecting tensorflow==2.2.0
#   Downloading https://files.pythonhosted.org/packages/3d/be/679ce5254a8c8d07470efb4a4c00345fae91f766e64f1c2aece8796d7218/tensorflow-2.2.0-cp36-cp36m-manylinux2010_x86_64.whl (516.2MB)
#      |████████████████████████████████| 516.2MB 32kB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (1.18.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (0.10.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (0.3.3)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (0.35.1)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (3.12.4)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (1.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (3.3.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (1.6.3)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/1d/74/0a6fcb206dcc72a6da9a62dd81784bfdbff5fedb099982861dc2219014fb/tensorboard-2.2.2-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 4.8MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (1.1.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (1.33.2)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (1.1.2)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/a4/f5/926ae53d6a226ec0fda5208e0e581cffed895ccc89e36ba76a8e60895b78/tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454kB)
#      |████████████████████████████████| 460kB 53.3MB/s
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.2.0) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow==2.2.0) (50.3.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.17.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.10)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.1.0)
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# Successfully installed tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0

# %%
# !pip install Keras==2.2.4
# Out:
# Collecting Keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 9.4MB/s
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 6.2MB/s
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras==2.2.4) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from Keras==2.2.4) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras==2.2.4) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras==2.2.4) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras==2.2.4) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras==2.2.4) (1.18.5)
# Installing collected packages: keras-applications, Keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed Keras-2.2.4 keras-applications-1.0.8

# %%
#import matplotlib with pdf as backend
import matplotlib 
matplotlib.use('PDF')
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

import wfdb
import os
import numpy as np
import math
import sys
import scipy.stats as st
import glob, os
from os.path import basename
import pandas as pd
from pathlib import Path
from wfdb import processing


import tensorflow as tf
from keras.layers import Dense,Activation,Dropout
from keras.layers import LSTM,Bidirectional #could try TimeDistributed(Dense(...))
from keras.models import Sequential, load_model
from keras import optimizers,regularizers
from keras.layers.normalization import BatchNormalization

###
## ORIGINAL import keras.backend.tensorflow_backend as KTF
from tensorflow.python.keras.backend import set_session as KTF
## from tensorflow.python.keras import backend as KTF

np.random.seed(0)

# %%
def splitseq(x,n,o):
	#split seq; should be optimized so that remove_seq_gaps is not needed. 
	upper=math.ceil( x.shape[0] / n) *n
	print("splitting on",n,"with overlap of ",o,	"total datapoints:",x.shape[0],"; upper:",upper)
	for i in range(0,upper,n):
		#print(i)
		if i==0:
			padded=np.zeros( ( o+n+o,x.shape[1])   ) ## pad with 0's on init
			padded[o:,:x.shape[1]] = x[i:i+n+o,:]
			xpart=padded
		else:
			xpart=x[i-o:i+n+o,:]
		if xpart.shape[0]<i:

			padded=np.zeros( (o+n+o,xpart.shape[1])  ) ## pad with 0's on end of seq
			padded[:xpart.shape[0],:xpart.shape[1]] = xpart
			xpart=padded

		xpart=np.expand_dims(xpart,0)## add one dimension; so that you get shape (samples,timesteps,features)
		try:
			xx=np.vstack(  (xx,xpart) )
		except UnboundLocalError: ## on init
			xx=xpart
	print("output: ",xx.shape)
	return(xx)

# %%
def remove_seq_gaps(x,y):
	#remove parts that are not annotated <- not ideal, but quickest for now.
	window=150
	c=0
	cutout=[]
	include=[]
	print("filterering.")
	print("before shape x,y",x.shape,y.shape)
	for i in range(y.shape[0]):
		
		c=c+1
		if c<window :
			include.append(i)
		if sum(y[i,0:5])>0:
			c=0 
		if c >= window:
			#print ('filtering')
			pass
	x,y=x[include,:],y[include,:]
	print(" after shape x,y",x.shape,y.shape)
	return(x,y)

# %%
def normalizesignal(x):
	x=st.zscore(x, ddof=0)
	return x
def normalizesignal_array(x):
	for i in range(x.shape[0]):
		x[i]=st.zscore(x[i], axis=0, ddof=0)
	return x

# %%
def plotecg(x,y,begin,end):
	#helper to plot ecg
	plt.figure(1,figsize=(11.69,8.27))
	plt.subplot(211)
	plt.plot(x[begin:end,0])
	plt.subplot(211)
	plt.plot(y[begin:end,0])
	plt.subplot(211)
	plt.plot(y[begin:end,1])
	plt.subplot(211)
	plt.plot(y[begin:end,2])
	plt.subplot(211)
	plt.plot(y[begin:end,3])
	plt.subplot(211)
	plt.plot(y[begin:end,4])
	plt.subplot(211)
	plt.plot(y[begin:end,5])

	plt.subplot(212)
	plt.plot(x[begin:end,1])
	plt.show()

# %%
def plotecg_validation(x,y_true,y_pred,begin,end):
	#helper to plot ecg
	plt.figure(1,figsize=(11.69,8.27))
	plt.subplot(211)
	plt.plot(x[begin:end,0])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,0])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,1])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,2])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,3])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,4])
	plt.subplot(211)
	plt.plot(y_pred[begin:end,5])

	plt.subplot(212)
	plt.plot(x[begin:end,1])
	plt.subplot(212)
	plt.plot(y_true[begin:end,0])
	plt.subplot(212)
	plt.plot(y_true[begin:end,1])
	plt.subplot(212)
	plt.plot(y_true[begin:end,2])
	plt.subplot(212)
	plt.plot(y_true[begin:end,3])
	plt.subplot(212)
	plt.plot(y_true[begin:end,4])
	plt.subplot(212)
	plt.plot(y_true[begin:end,5])

# %%
def LoaddDatFiles(datfiles):  
	for datfile in datfiles:
	    print(datfile)
	    if basename(datfile).split(".",1)[0] in exclude:
	    	continue
	    qf=os.path.splitext(datfile)[0]+'.q1c'
	    if os.path.isfile(qf):
	    	#print("yes",qf,datfile)
	    	x,y=get_ecg_data(datfile)
	    	x,y=remove_seq_gaps(x,y)

	    	x,y=splitseq(x,1000,150),splitseq(y,1000,150) ## create equal sized numpy arrays of n size and overlap of o 

	    	x = normalizesignal_array(x)
	    	## todo; add noise, shuffle leads etc. ?
	    	try: ## concat
	    		xx=np.vstack(  (xx,x) )
	    		yy=np.vstack(  (yy,y) )
	    	except NameError: ## if xx does not exist yet (on init)
	    		xx = x
	    		yy = y
	return(xx,yy)

# %%
def unison_shuffled_copies(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# %%
def get_session(gpu_fraction=0.8):
	#allocate % of gpu memory.
	num_threads = os.environ.get('OMP_NUM_THREADS')
	gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=gpu_fraction)
	if num_threads:
		return tf.Session(config=tf.ConfigProto(gpu_options=gpu_options, intra_op_parallelism_threads=num_threads))
	else:
		return tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
def getmodel():
	model = Sequential()
	model.add(Dense(32,W_regularizer=regularizers.l2(l=0.01), input_shape=(seqlength, features)))
	model.add(Bidirectional(LSTM(32, return_sequences=True)))#, input_shape=(seqlength, features)) ) ### bidirectional ---><---
	model.add(Dropout(0.2))
	model.add(BatchNormalization())
	model.add(Dense(64, activation='relu',W_regularizer=regularizers.l2(l=0.01)))
	model.add(Dropout(0.2))
	model.add(BatchNormalization())
	model.add(Dense(dimout, activation='softmax'))
	adam = optimizers.adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
	model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy']) 
	print(model.summary())
	return(model)

# %%
##################################################################
##################################################################
folder_path='/content/physionet.org/files/ludb/1.0.0' ## first argument = qtdb database from physionet. 
perct=0.81 #percentage training
percv=0.19 #percentage validation

#exclude = set()
#exclude.update(["sel35","sel36","sel37","sel50","sel102","sel104","sel221","sel232", "sel310"])# no P annotated:
##################################################################
# datfile=qtdbpath+"sel49.dat"  ## single ECG to test if loading works.  
# x,y=get_ecg_data(datfile)
# print(x.shape,y.shape)
# # for i in range(y.shape[0]): #Invert QT-label to actually represent QT. Does give overlapping labels
# # 	y[i][0] = 1 - y[i][0]
# plotecg(x,y,0,y.shape[0]) ## plot all
# x,y=remove_seq_gaps(x,y) ## remove 'annotation gaps'
# plotecg(x,y,0,y.shape[0]) ## plot all
# x,y=splitseq(x,750,150),splitseq(y,750,150) ## create equal sized numpy arrays of n size and overlap of o 
# exit()
##################################################################

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fd922c5def22> in <module>()
# ----> 1 print(xxt)
#
# NameError: name 'xxt' is not defined

# %%
# load data
# datfiles
file_list = os.listdir(folder_path)
record_list = pd.read_csv(os.path.join(folder_path,'RECORDS')).values.ravel()

xxt,yyt=LoaddDatFiles(file_list[ :round(len(file_list)*perct) ]) # training data. 
xxt,yyt=unison_shuffled_copies(xxt,yyt) ### shuffle
xxv,yyv=LoaddDatFiles(file_list[ -round(len(file_list)*percv): ] ) ## validation data.
seqlength=xxt.shape[1]
features=xxt.shape[2]
dimout=yyt.shape[2]
print("xxv/validation shape: {}, Seqlength: {}, Features: {}".format(xxv.shape[0],seqlength,features))
# #plot validation ecgs 
# with PdfPages('ecgs_xxv.pdf') as pdf:
# 	for i in range( xxv.shape[0] ): 
# 		print (i)
# 		plotecg(xxv[i,:,:],yyv[i,:,:],0,yyv.shape[1])
# 		pdf.savefig()
# 		plt.close()
# Out:
# 141.atr_v2
# 115.atr_v1
# 96.atr_avf
# 28.atr_v1
# 158.atr_v4
# 89.atr_avl
# 2.atr_i
# 126.atr_i
# 78.atr_iii
# 19.atr_v2
# 24.atr_iii
# 105.atr_avf
# 32.atr_v1
# 162.atr_v1
# 56.atr_v4
# 12.atr_v1
# 167.atr_v5
# 72.atr_v3
# 45.atr_avf
# 3.atr_ii
# 187.atr_ii
# 35.atr_v2
# 177.atr_v5
# 199.atr_avr
# 6.atr_v1
# 1.atr_iii
# 92.atr_v3
# 34.atr_v6
# 22.dat
# 31.atr_avf
# 160.atr_i
# 31.atr_v3
# 39.hea
# 112.atr_v1
# 106.atr_v5
# 23.atr_v6
# 146.atr_avl
# 20.atr_v3
# 65.atr_ii
# 115.atr_v5
# 52.atr_i
# 199.atr_v1
# 170.hea
# 87.atr_v5
# 40.atr_ii
# 95.atr_v4
# 47.atr_avr
# 146.atr_v3
# 165.dat
# 80.atr_v3
# 42.atr_iii
# 189.atr_v6
# 96.atr_v6
# 76.atr_ii
# 127.atr_ii
# 200.atr_v1
# 8.dat
# 17.atr_v6
# 25.atr_iii
# 43.dat
# 116.atr_v2
# 104.atr_ii
# 152.atr_avr
# 21.atr_v3
# 164.atr_v6
# 18.atr_avl
# 72.atr_v6
# 118.atr_avf
# 28.atr_ii
# 145.atr_avf
# 177.hea
# 52.atr_v2
# 65.atr_i
# 109.dat
# 68.atr_ii
# 198.atr_i
# 147.atr_v1
# 39.atr_avf
# 46.atr_v1
# 125.atr_v1
# 10.atr_v4
# 71.atr_avl
# 1.atr_v2
# 1.hea
# 104.atr_avf
# 116.atr_avl
# 184.atr_v4
# 12.atr_v3
# 35.atr_v5
# 149.atr_v5
# 71.atr_v1
# 33.atr_i
# 17.atr_avr
# 166.atr_avf
# 147.atr_v6
# 88.atr_v5
# 69.atr_avl
# 5.atr_v6
# 71.atr_v5
# 198.dat
# 123.atr_v1
# 80.atr_v5
# 91.atr_v6
# 162.atr_avr
# 8.atr_iii
# 16.atr_avl
# 23.atr_v1
# 158.atr_ii
# 155.atr_avl
# 3.atr_v5
# 153.atr_v2
# 192.atr_avl
# 142.atr_avr
# 102.atr_v2
# 32.atr_v6
# 99.hea
# 69.atr_v5
# 17.atr_ii
# 119.atr_ii
# 61.atr_v2
# 193.atr_v2
# 70.atr_v2
# 97.dat
# 197.atr_v6
# 103.atr_ii
# 64.atr_v2
# 168.atr_v4
# 117.atr_i
# 194.atr_ii
# 24.atr_i
# 40.atr_v6
# 135.atr_avf
# 97.atr_ii
# 189.atr_v1
# 123.atr_v6
# 131.atr_avl
# 99.atr_avl
# 177.atr_v1
# 200.atr_i
# 180.atr_v6
# 163.atr_avr
# 47.atr_ii
# 5.atr_avr
# 27.atr_avf
# 76.atr_avl
# 190.atr_avf
# 72.atr_avr
# 174.atr_iii
# 127.atr_avr
# 117.atr_v6
# 93.atr_v3
# 90.atr_v2
# 186.atr_i
# 84.atr_v4
# 126.atr_avr
# 45.atr_iii
# 171.atr_v4
# 108.atr_ii
# 159.hea
# 97.atr_v1
# 86.atr_v2
# 82.dat
# 191.atr_i
# 73.atr_i
# 99.atr_v1
# 144.atr_v3
# 8.atr_v1
# 142.atr_i
# 115.atr_avr
# 91.atr_v1
# 38.atr_avf
# 179.atr_iii
# 158.atr_v6
# 26.atr_avl
# 172.atr_v3
# 74.atr_v1
# 130.atr_avl
# 176.atr_avf
# 124.atr_i
# 131.atr_v5
# 29.atr_iii
# 120.atr_ii
# 168.atr_v2
# 172.atr_v6
# 57.atr_v3
# 89.dat
# 9.atr_v2
# 22.atr_ii
# 171.atr_v6
# 22.atr_v2
# 13.atr_v5
# 142.atr_v4
# 127.atr_v4
# 200.dat
# 79.hea
# 81.atr_v1
# 40.atr_v4
# 42.atr_v5
# 166.atr_avr
# 152.atr_v2
# 160.atr_v3
# 172.atr_i
# 149.atr_ii
# 50.atr_v4
# 89.atr_ii
# 72.dat
# 27.atr_v3
# 15.atr_iii
# 180.atr_iii
# 10.atr_avl
# 163.atr_ii
# 13.dat
# 64.atr_v3
# 165.atr_avr
# 105.atr_v5
# 165.atr_v4
# 117.dat
# 115.atr_v2
# 57.atr_ii
# 24.dat
# 89.atr_v1
# 133.atr_avf
# 47.atr_iii
# 14.atr_v4
# 101.atr_i
# 196.dat
# 92.atr_v6
# 9.atr_avr
# 126.atr_v3
# 53.atr_v1
# 127.atr_v6
# 178.atr_ii
# 12.atr_v5
# 6.dat
# 24.atr_v4
# 168.atr_v3
# 154.dat
# 105.atr_v3
# 195.hea
# 194.atr_avr
# 194.dat
# 79.atr_v3
# 63.atr_ii
# 189.atr_avf
# 165.atr_v1
# 146.atr_iii
# 72.atr_v5
# 122.dat
# 144.atr_v4
# 185.atr_avl
# 53.atr_avr
# 125.atr_ii
# 137.atr_v5
# 95.atr_v3
# 125.atr_v5
# 4.atr_v5
# 50.atr_ii
# 178.atr_v2
# 31.atr_iii
# 181.atr_iii
# 21.atr_ii
# 109.atr_ii
# 165.hea
# 84.atr_ii
# 20.atr_avf
# 125.atr_v4
# 35.atr_v3
# 103.atr_iii
# 6.atr_iii
# 102.hea
# 193.atr_v5
# 195.atr_v2
# 148.dat
# 185.atr_ii
# 37.atr_v1
# 152.atr_avl
# 4.hea
# 46.atr_i
# 20.atr_v5
# 43.atr_v2
# 66.dat
# 80.hea
# 50.atr_v6
# 23.atr_i
# 195.dat
# 151.hea
# 190.atr_v5
# 172.atr_v2
# 67.atr_i
# 174.atr_ii
# 7.atr_avf
# 36.atr_v5
# 159.atr_avf
# 70.atr_v6
# 30.atr_v5
# 146.atr_v1
# 177.atr_v3
# 183.atr_v6
# 110.atr_v4
# 62.atr_avl
# 138.atr_v2
# 147.atr_v5
# 5.atr_iii
# 189.atr_avl
# 19.atr_v1
# 109.atr_v6
# 19.atr_v5
# 64.atr_v5
# 123.atr_iii
# 78.atr_avf
# 26.atr_ii
# 198.hea
# 75.atr_v2
# 33.atr_v3
# 78.hea
# 87.atr_avl
# 150.atr_avr
# 117.atr_avf
# 107.atr_avr
# 22.atr_v5
# 118.atr_avl
# 81.atr_v3
# 44.atr_v6
# 176.atr_v5
# 16.atr_v4
# 185.atr_v6
# 75.atr_v4
# 95.atr_v1
# 180.atr_v3
# 6.atr_v2
# 145.dat
# 136.atr_v4
# 143.atr_avr
# 18.atr_v5
# 51.atr_avf
# 87.atr_ii
# 170.atr_v3
# 151.atr_v1
# 175.dat
# 182.atr_v4
# 94.atr_iii
# 100.hea
# 187.dat
# 146.atr_v4
# 168.atr_v5
# 86.atr_v3
# 1.atr_ii
# 106.atr_avl
# 121.atr_v3
# 20.atr_avr
# 105.dat
# 169.atr_v2
# 142.atr_v5
# 18.dat
# 178.atr_v1
# 21.atr_avr
# 41.atr_v6
# 170.atr_avr
# 86.atr_avf
# 136.atr_iii
# 189.atr_ii
# 16.atr_ii
# 111.atr_avr
# 36.atr_v6
# 172.atr_iii
# 21.atr_v4
# 187.atr_v2
# 4.atr_i
# 142.hea
# 136.atr_avl
# 118.atr_ii
# 47.atr_v6
# 185.atr_v5
# 127.hea
# 153.dat
# 167.dat
# 12.atr_avl
# 60.hea
# 149.atr_v4
# 147.atr_avr
# 165.atr_ii
# 17.atr_v4
# 161.atr_avl
# 27.dat
# 29.atr_ii
# 176.atr_ii
# 98.atr_v2
# 78.atr_v6
# 20.atr_v4
# 125.atr_i
# 164.atr_ii
# 170.atr_v4
# 49.atr_iii
# 83.atr_avf
# 121.atr_v5
# 129.dat
# 68.atr_v5
# 170.atr_v1
# 90.atr_v1
# 197.atr_ii
# 33.atr_avr
# 166.atr_avl
# 119.hea
# 59.atr_v2
# 139.atr_v2
# 94.atr_v2
# 166.atr_i
# 75.atr_v1
# 163.atr_avl
# 98.atr_avr
# 70.atr_avr
# 24.atr_v2
# 67.dat
# 114.atr_avf
# 161.atr_i
# 123.atr_v2
# 166.atr_v1
# 47.dat
# 130.atr_iii
# 71.dat
# 180.hea
# 171.atr_v5
# 190.atr_i
# 59.atr_v1
# 86.atr_ii
# 42.dat
# 81.atr_ii
# 43.atr_v3
# 183.atr_v4
# 117.atr_avr
# 68.atr_iii
# 135.atr_avl
# 15.atr_v4
# 139.atr_avl
# 85.atr_avr
# 77.atr_v2
# 103.atr_v1
# 160.atr_v1
# 189.atr_v3
# 174.atr_avl
# 184.atr_ii
# 7.atr_avr
# 137.atr_ii
# 178.atr_v3
# 149.atr_iii
# 139.atr_v4
# 181.atr_i
# 40.atr_avr
# 98.atr_i
# 101.dat
# 93.dat
# 97.atr_avl
# 86.atr_avl
# 157.atr_v1
# 181.atr_avl
# 167.atr_v6
# 147.atr_v4
# 182.atr_v2
# 83.hea
# 71.hea
# 154.atr_v3
# 169.atr_ii
# 154.atr_avr
# 39.atr_avl
# 169.atr_avl
# 163.atr_v1
# 157.atr_avf
# 129.atr_v1
# 134.atr_v3
# 103.atr_v2
# 136.atr_v2
# 19.atr_avf
# 104.hea
# 92.atr_v1
# 161.atr_ii
# 84.atr_v1
# 119.dat
# 94.atr_ii
# 76.atr_v6
# 200.atr_avf
# 74.atr_ii
# 94.atr_v4
# 52.atr_iii
# 137.atr_v2
# 143.hea
# 47.atr_v2
# 73.atr_iii
# 39.atr_i
# 77.atr_v6
# 114.atr_iii
# 94.atr_v3
# 40.dat
# 199.atr_v5
# 96.atr_ii
# 3.atr_avl
# 197.atr_v1
# 160.atr_v4
# 81.atr_i
# 179.atr_avf
# 90.atr_avr
# 3.atr_v3
# 29.atr_v6
# 152.atr_iii
# 32.atr_v2
# 11.atr_v1
# 133.atr_ii
# 29.atr_avl
# 151.atr_avf
# 77.atr_avf
# 79.dat
# 2.atr_v4
# 191.atr_v6
# 81.dat
# 127.atr_v2
# 47.atr_avf
# 79.atr_iii
# 83.atr_v4
# 182.atr_i
# 20.atr_avl
# 104.atr_iii
# 51.atr_v3
# 4.atr_v1
# 115.atr_v6
# 196.atr_v3
# 63.atr_v3
# 76.atr_v3
# 41.dat
# 176.dat
# 86.atr_avr
# 66.hea
# 15.atr_ii
# 166.atr_v6
# 152.dat
# 84.atr_avr
# 30.atr_v4
# 136.atr_v5
# 150.hea
# 132.atr_v5
# 9.atr_avl
# 64.atr_iii
# 107.atr_v4
# 79.atr_v6
# 115.atr_avl
# 155.atr_v3
# 142.atr_v1
# 74.atr_avl
# 157.atr_iii
# 99.atr_avf
# 62.atr_i
# 183.atr_avl
# 195.atr_v3
# 36.atr_v1
# 144.atr_v2
# 5.atr_v3
# 126.atr_v4
# 44.atr_avl
# 24.atr_avf
# 106.atr_v1
# 140.atr_v6
# 132.atr_avf
# 131.atr_v3
# 18.atr_v6
# 53.dat
# 172.atr_v5
# 6.atr_avf
# 164.atr_v2
# 160.dat
# 104.atr_v1
# 181.atr_v5
# 91.atr_avf
# 50.hea
# 135.atr_i
# 144.dat
# 62.atr_avr
# 65.atr_avr
# 140.atr_v4
# 14.atr_iii
# 185.atr_iii
# 127.atr_v5
# 109.atr_avr
# 146.hea
# 122.atr_v4
# 168.atr_v6
# 166.atr_ii
# 13.atr_avf
# 74.atr_v3
# 9.atr_avf
# 111.atr_v1
# 129.atr_v3
# 24.atr_v1
# 66.atr_avr
# 166.dat
# 169.atr_v5
# 1.atr_avr
# 150.atr_ii
# 142.atr_v6
# 199.atr_v2
# 53.atr_v4
# 163.atr_avf
# 153.atr_iii
# 88.atr_v2
# 183.atr_v3
# 168.atr_ii
# 121.hea
# 197.atr_avl
# 62.hea
# 148.hea
# 147.atr_v2
# 69.atr_i
# 37.atr_v4
# 48.atr_avr
# 72.hea
# 14.atr_v1
# 14.atr_avl
# 62.atr_v6
# 76.atr_avf
# 180.atr_v5
# 197.dat
# 126.atr_avl
# 150.atr_iii
# 188.dat
# 3.atr_v1
# 46.atr_avr
# 65.atr_v5
# 27.atr_v1
# 170.atr_i
# 19.atr_v6
# 179.atr_v5
# 13.atr_ii
# 108.atr_i
# 159.atr_i
# 109.hea
# 27.atr_avr
# 92.atr_v5
# 158.atr_iii
# 196.atr_v2
# 68.atr_v6
# 62.atr_iii
# 84.atr_v2
# 198.atr_ii
# 113.atr_v2
# 78.atr_v5
# 70.dat
# 88.dat
# 138.dat
# 64.atr_avr
# 89.atr_v4
# 67.atr_v6
# 93.atr_i
# 29.atr_avf
# 104.atr_i
# 151.atr_v5
# 148.atr_v4
# 37.atr_avf
# 125.atr_v3
# 183.atr_i
# 127.dat
# 190.atr_v4
# 141.atr_ii
# 26.atr_i
# 25.atr_i
# 50.atr_v2
# 88.atr_avr
# 25.atr_avl
# 116.atr_v5
# 153.atr_ii
# 111.atr_v5
# 53.atr_i
# 188.atr_v1
# 110.atr_avr
# 92.atr_ii
# 73.atr_v4
# 96.atr_i
# 2.atr_v1
# 134.atr_v2
# 80.atr_v1
# 138.atr_avl
# 61.atr_i
# 99.atr_v5
# 58.atr_v3
# 85.atr_iii
# 145.atr_ii
# 59.atr_v3
# 165.atr_i
# SHA256SUMS.txt
# 153.atr_v6
# 91.atr_v3
# 22.atr_avf
# 145.atr_avr
# 36.atr_avl
# 199.atr_iii
# 200.atr_v5
# 77.atr_v1
# 194.atr_v4
# 10.atr_i
# 38.atr_iii
# 25.atr_avf
# 4.atr_iii
# 37.atr_iii
# 197.atr_iii
# 34.atr_v3
# 43.atr_v6
# 119.atr_v5
# 39.atr_v3
# 115.atr_iii
# 43.atr_iii
# 106.atr_avr
# 195.atr_iii
# 57.atr_v1
# 94.atr_avf
# 100.atr_v6
# 164.atr_i
# 18.atr_iii
# 151.dat
# 196.atr_i
# 170.atr_v6
# 41.atr_avf
# 174.atr_v6
# 6.atr_ii
# 97.hea
# 70.hea
# 52.atr_v5
# 65.atr_avl
# 67.atr_v2
# 27.atr_iii
# 154.atr_v5
# 72.atr_avl
# 5.atr_v1
# 33.atr_avl
# 162.atr_v2
# 110.dat
# 136.atr_ii
# 57.atr_i
# 192.dat
# 168.atr_avf
# 138.atr_v3
# 77.atr_avr
# 154.atr_v2
# 106.atr_v4
# 133.atr_v1
# 144.atr_ii
# 142.atr_avl
# 133.atr_v2
# 95.atr_v6
# 132.atr_i
# 175.atr_ii
# 131.atr_v2
# 164.atr_avr
# 95.atr_avr
# 88.atr_ii
# 188.atr_v6
# 191.atr_avr
# 32.atr_avl
# 148.atr_avf
# 74.atr_iii
# 7.atr_v3
# 10.atr_avf
# 45.atr_avl
# 22.atr_avl
# 167.atr_v3
# 35.atr_i
# 34.atr_v1
# 194.atr_avf
# 7.hea
# 57.atr_v4
# 174.atr_v5
# 154.atr_ii
# 28.atr_i
# 91.atr_i
# 155.hea
# 70.atr_iii
# 190.atr_v1
# 91.atr_v5
# 200.atr_v6
# 45.atr_v3
# 63.atr_avr
# 33.atr_iii
# 38.atr_v1
# 76.atr_v5
# 74.hea
# 151.atr_iii
# 98.atr_v4
# 118.atr_avr
# 62.atr_v1
# 173.atr_i
# 93.atr_v5
# 112.atr_v5
# 111.atr_ii
# 80.dat
# 167.atr_avf
# 51.atr_iii
# 197.atr_v3
# 96.hea
# 158.atr_i
# 48.atr_v3
# 164.atr_v3
# 73.hea
# 120.atr_v6
# 32.atr_v5
# 68.atr_i
# 41.atr_v3
# 64.atr_avl
# 179.atr_ii
# 118.atr_iii
# 27.atr_v5
# 82.atr_v5
# 125.atr_avf
# 102.atr_ii
# 86.atr_v1
# 126.atr_v1
# 75.dat
# 34.atr_i
# 54.dat
# 52.atr_v1
# 44.atr_i
# 97.atr_avr
# 9.hea
# 24.hea
# 3.atr_v2
# 100.atr_v1
# 61.atr_v3
# 89.atr_v2
# 55.atr_iii
# 103.atr_v6
# 188.atr_avf
# 32.atr_avf
# 177.atr_avr
# 137.atr_iii
# 45.atr_v6
# 68.dat
# 182.atr_avr
# 2.atr_avf
# 178.atr_v4
# 200.atr_iii
# 200.atr_v2
# 120.atr_avr
# 54.atr_i
# 182.atr_iii
# 56.atr_v5
# 144.atr_avl
# 6.atr_avl
# 160.atr_avr
# 101.atr_ii
# 107.dat
# 147.atr_i
# 78.atr_v4
# 13.atr_iii
# 71.atr_avr
# 100.atr_iii
# 138.atr_i
# 125.hea
# 120.atr_avl
# 133.atr_v4
# 6.atr_i
# 85.atr_i
# 35.atr_v6
# 193.atr_avl
# 8.atr_v6
# 81.atr_v4
# 154.atr_v4
# 106.atr_iii
# 193.dat
# 46.atr_v4
# 112.atr_ii
# 70.atr_avl
# 2.atr_avr
# 92.hea
# 174.dat
# 189.atr_v2
# 159.dat
# 190.atr_ii
# 198.atr_avr
# 75.atr_avl
# 40.atr_v5
# 106.dat
# 183.atr_v2
# 112.atr_v2
# 163.atr_v3
# RECORDS
# 57.atr_v5
# 59.atr_i
# 29.atr_i
# 58.atr_avr
# 113.atr_v3
# 4.atr_avf
# 77.atr_ii
# 129.atr_i
# 128.atr_avr
# 147.atr_ii
# 111.atr_v3
# 21.atr_i
# 46.atr_v3
# 70.atr_v4
# 188.atr_v3
# 189.atr_avr
# 187.atr_v5
# 140.atr_avr
# 170.atr_v5
# 92.atr_v4
# 163.atr_iii
# 136.atr_v3
# 160.atr_v5
# 142.atr_v3
# 153.atr_i
# 58.atr_v1
# 154.atr_v1
# 162.dat
# 43.atr_avr
# 24.atr_avl
# 119.atr_v6
# 177.atr_v4
# 141.dat
# 169.atr_iii
# 42.atr_i
# 26.atr_v3
# 48.atr_i
# 59.atr_v5
# 181.hea
# 183.atr_v5
# 36.atr_ii
# 60.atr_v3
# 57.atr_avl
# 56.atr_ii
# 19.atr_v4
# 139.hea
# 72.atr_ii
# 8.atr_v5
# 79.atr_avl
# 146.atr_v5
# 62.atr_v5
# 53.atr_v2
# 200.atr_avl
# 65.atr_v4
# 8.atr_avf
# 104.atr_avl
# 171.atr_i
# 147.atr_v3
# 162.atr_v6
# 10.atr_ii
# 170.atr_avl
# 79.atr_avr
# 51.atr_avr
# 30.atr_v2
# 99.atr_avr
# 12.atr_i
# 54.atr_iii
# 158.atr_v3
# 103.atr_v4
# 63.atr_v2
# 130.atr_v1
# 81.hea
# 144.atr_v1
# 60.atr_v4
# 66.atr_v5
# 194.hea
# 157.atr_avl
# 11.atr_v2
# 102.atr_iii
# 103.atr_i
# 124.atr_v5
# 9.atr_ii
# 171.atr_v1
# 108.atr_v6
# 199.atr_v3
# 143.atr_avl
# 175.hea
# 146.atr_i
# 38.atr_v5
# 62.atr_avf
# 112.atr_avl
# 38.atr_v4
# 8.hea
# 93.atr_v1
# 160.atr_v6
# 22.atr_v1
# 65.atr_avf
# 193.atr_avf
# 192.atr_v4
# 175.atr_v2
# 91.atr_v2
# 152.atr_avf
# 112.atr_avr
# 148.atr_v2
# 34.atr_avf
# 85.atr_v2
# 72.atr_v2
# 87.atr_v1
# 32.atr_v3
# 191.atr_iii
# 177.dat
# 166.atr_v2
# 59.atr_avr
# 157.hea
# 176.atr_v4
# 18.atr_v3
# 46.atr_ii
# 186.atr_avr
# 122.atr_v5
# 119.atr_i
# 83.atr_v1
# 65.hea
# 49.atr_avl
# 27.atr_v4
# 119.atr_avr
# 136.atr_avr
# 114.atr_v3
# 31.atr_v2
# 148.atr_ii
# 194.atr_v6
# 12.atr_avf
# 10.atr_v1
# 92.atr_avf
# 184.atr_v6
# 141.atr_avl
# 188.atr_iii
# 151.atr_i
# 126.dat
# 178.atr_v6
# 115.atr_v3
# 198.atr_avl
# 156.atr_v4
# 185.atr_i
# 143.dat
# 4.atr_ii
# 58.atr_iii
# 185.atr_v4
# 12.dat
# 153.atr_v3
# 93.hea
# 19.atr_ii
# 2.atr_iii
# 73.atr_avf
# 142.dat
# 48.atr_v2
# 135.atr_v3
# 160.atr_avf
# 96.atr_v1
# 23.atr_v5
# 13.atr_avl
# 142.atr_v2
# 191.atr_v2
# 44.dat
# 150.atr_v1
# 176.atr_v6
# 166.hea
# 31.atr_v5
# 54.atr_v5
# 101.atr_v5
# 129.atr_v6
# 42.atr_v2
# 49.atr_i
# 8.atr_v2
# 23.atr_ii
# 83.atr_v6
# 63.atr_i
# 127.atr_iii
# 141.atr_v1
# 37.hea
# 121.atr_i
# 128.dat
# 124.hea
# 124.atr_v2
# 118.atr_v1
# 8.atr_avr
# 130.atr_avr
# 196.atr_ii
# 144.hea
# 193.atr_v4
# 199.hea
# 60.atr_i
# 110.atr_v3
# 190.atr_avl
# 30.hea
# 142.atr_ii
# 91.atr_avl
# 139.atr_v5
# 8.atr_i
# 113.atr_v6
# 184.atr_iii
# 39.atr_ii
# 56.atr_v6
# 12.atr_v6
# 172.atr_ii
# 77.dat
# 73.atr_v2
# 66.atr_iii
# 87.atr_v3
# 14.hea
# 118.atr_v4
# 114.atr_v5
# 185.atr_v2
# 30.dat
# 56.hea
# 61.atr_avl
# 66.atr_v2
# 94.atr_v6
# 45.atr_v4
# 154.hea
# 39.dat
# 72.atr_v4
# 43.atr_avl
# 141.atr_i
# 168.atr_avl
# 11.atr_ii
# 90.hea
# 148.atr_i
# 139.atr_avr
# 190.atr_v3
# 32.atr_iii
# 5.atr_ii
# 13.atr_v6
# 71.atr_avf
# 90.atr_i
# 111.atr_iii
# 113.atr_v1
# 128.atr_avl
# 144.atr_avr
# 124.atr_v4
# 117.atr_v5
# 133.atr_i
# 199.atr_v6
# 42.atr_ii
# 57.atr_v2
# 185.dat
# 67.atr_iii
# 21.hea
# 83.atr_ii
# 191.atr_avl
# 1.atr_v5
# 177.atr_avl
# 106.atr_ii
# 136.atr_v1
# 174.atr_avr
# 68.atr_avl
# 60.atr_avf
# 63.atr_v5
# 66.atr_i
# 129.atr_avl
# 50.atr_v5
# 106.atr_v6
# 163.atr_v4
# 102.atr_avr
# 46.atr_v2
# 80.atr_avr
# 153.hea
# 137.atr_avl
# 115.hea
# 129.atr_iii
# 82.hea
# 162.atr_v4
# 37.atr_v5
# 136.atr_v6
# 85.atr_v4
# 153.atr_avl
# 176.atr_i
# 149.atr_v6
# 27.hea
# 10.atr_v3
# 40.atr_avf
# 15.atr_avf
# 123.atr_v3
# 65.atr_iii
# 184.atr_v3
# 122.atr_v6
# 55.atr_v4
# 89.atr_v5
# 102.atr_avl
# 82.atr_v6
# 37.atr_v3
# 31.atr_v1
# 74.atr_avf
# 145.atr_iii
# 129.hea
# 131.dat
# 116.atr_avr
# 42.atr_v6
# 132.atr_avl
# 116.atr_avf
# 49.atr_v4
# 120.atr_v3
# 148.atr_v5
# 155.atr_avf
# 173.atr_avr
# 76.atr_v4
# 69.atr_avf
# 21.atr_avf
# 22.atr_v3
# 71.atr_v6
# 128.atr_ii
# 85.hea
# 192.atr_v6
# 35.atr_avr
# 181.atr_v2
# 59.atr_avl
# 161.atr_avf
# 149.atr_v1
# 6.atr_avr
# 78.atr_avr
# 84.atr_v3
# 197.hea
# 68.atr_v4
# 187.atr_iii
# 156.atr_v6
# 33.atr_v1
# 107.atr_v5
# 108.hea
# 31.atr_v4
# 18.atr_v1
# 100.atr_avr
# 110.atr_v1
# 156.atr_ii
# 101.atr_avf
# 5.atr_avl
# 3.atr_avr
# 138.hea
# 180.atr_v1
# 46.atr_avf
# 54.atr_v3
# 96.atr_v4
# 78.atr_i
# 38.atr_v6
# 35.atr_iii
# 134.atr_avr
# 131.atr_v1
# 198.atr_iii
# 31.dat
# 51.atr_v2
# 149.hea
# 32.atr_avr
# 121.atr_v6
# 133.hea
# 119.atr_avl
# 1.atr_avf
# 75.atr_avr
# 45.atr_i
# 188.atr_avl
# 195.atr_avr
# 63.hea
# 61.atr_ii
# 186.atr_v5
# 82.atr_avr
# 29.atr_v4
# 155.atr_v6
# 24.atr_v3
# 71.atr_iii
# 40.atr_avl
# 78.atr_v1
# 124.atr_v1
# 149.atr_avr
# 141.atr_avf
# 14.atr_ii
# 10.dat
# 131.atr_i
# 20.atr_v6
# 101.atr_avr
# 65.atr_v6
# 117.atr_v3
# 32.hea
# 57.hea
# 26.dat
# 119.atr_v3
# 39.atr_v1
# 167.atr_i
# 145.atr_v2
# 94.dat
# 25.dat
# 112.atr_v3
# 15.atr_avl
# 42.atr_v3
# 194.atr_v3
# 103.atr_v5
# 80.atr_v2
# 184.atr_avf
# 138.atr_avr
# 179.dat
# 100.atr_v4
# 104.dat
# 56.atr_v2
# 44.atr_v4
# 145.atr_avl
# 181.atr_v3
# 55.atr_v1
# 87.dat
# 104.atr_avr
# 169.atr_v4
# 178.atr_iii
# 71.atr_v3
# 7.atr_iii
# 91.hea
# 18.atr_i
# 91.atr_v4
# 177.atr_v6
# 114.atr_ii
# 168.atr_i
# 116.atr_ii
# 51.atr_v1
# 33.atr_v6
# 133.atr_v6
# 11.atr_v4
# 189.atr_v4
# 157.dat
# 16.atr_avf
# 14.atr_v5
# 159.atr_v2
# 130.atr_avf
# 110.hea
# 20.atr_iii
# 91.atr_iii
# 38.atr_avr
# 7.atr_v6
# 139.atr_ii
# 166.atr_v4
# 80.atr_avf
# 99.atr_ii
# 194.atr_v5
# 142.atr_iii
# 159.atr_v6
# 59.atr_v4
# 9.atr_iii
# 92.atr_i
# 26.atr_avf
# 22.atr_avr
# 77.atr_v5
# 141.atr_v5
# 174.hea
# 11.dat
# 180.dat
# 117.atr_v1
# 41.atr_v1
# 28.atr_avf
# 16.atr_v6
# 182.atr_v6
# 88.atr_v1
# 70.atr_i
# 4.atr_v2
# 112.hea
# 3.atr_i
# 60.dat
# 171.atr_v2
# 16.dat
# 127.atr_v1
# 113.atr_v4
# 79.atr_v1
# 165.atr_v2
# 25.hea
# 50.atr_v3
# 144.atr_v6
# 44.atr_v2
# 33.dat
# 183.atr_avr
# 94.atr_avl
# 124.atr_v6
# 83.atr_v2
# 131.atr_avf
# 162.atr_v3
# 200.atr_v3
# 143.atr_v3
# 51.atr_v5
# 2.atr_v2
# 44.atr_iii
# 170.atr_iii
# 44.atr_ii
# 27.atr_i
# 113.atr_avl
# 195.atr_v1
# 81.atr_avr
# 58.hea
# 22.atr_iii
# 200.hea
# 96.atr_avr
# 83.atr_avr
# 123.atr_v5
# 11.atr_v3
# 70.atr_v3
# 36.atr_avf
# 102.atr_v4
# 196.atr_v6
# 87.hea
# 182.atr_avl
# 34.atr_iii
# 156.atr_i
# 61.atr_v4
# 9.dat
# 89.atr_iii
# 1.atr_v1
# 138.atr_v4
# 113.atr_iii
# 120.atr_avf
# 36.hea
# 188.atr_ii
# 64.atr_avf
# 191.hea
# 156.hea
# 104.atr_v5
# 84.atr_i
# 8.atr_ii
# 87.atr_v4
# 67.atr_ii
# 102.atr_i
# 115.atr_ii
# 136.atr_i
# 12.atr_v4
# 139.atr_iii
# 197.atr_v4
# 144.atr_avf
# 126.atr_ii
# 55.atr_avr
# 171.atr_v3
# 159.atr_v3
# 132.atr_ii
# 109.atr_v4
# 187.atr_v6
# 155.atr_v4
# 180.atr_avr
# 18.atr_avf
# 156.atr_v3
# 56.atr_avl
# 189.atr_i
# 96.atr_v2
# 81.atr_avf
# 73.atr_ii
# 97.atr_i
# 100.atr_ii
# 152.atr_ii
# 173.dat
# 102.atr_avf
# 72.atr_v1
# 108.atr_v1
# 15.atr_avr
# 143.atr_v1
# 178.dat
# 65.atr_v3
# 130.atr_v6
# 199.atr_ii
# 176.atr_v2
# 93.atr_avr
# 11.atr_v6
# 169.hea
# 71.atr_v4
# 92.atr_v2
# 186.atr_v6
# 34.atr_ii
# 108.atr_v4
# 50.atr_avr
# 192.atr_i
# 116.hea
# 143.atr_iii
# 105.atr_avr
# 184.dat
# 84.dat
# 155.atr_v1
# 17.atr_i
# 158.atr_v5
# 68.atr_avf
# 116.atr_v4
# 145.atr_v5
# 30.atr_iii
# 59.atr_v6
# 148.atr_v3
# 90.atr_v3
# 123.atr_avr
# 125.dat
# 171.dat
# 60.atr_avl
# 54.atr_avl
# 153.atr_v4
# 4.atr_avr
# 16.atr_iii
# 198.atr_v5
# 196.hea
# 55.atr_v6
# 122.atr_avr
# 72.atr_i
# 42.hea
# 135.atr_v2
# 178.atr_avl
# 49.atr_v6
# 173.atr_ii
# 184.hea
# 151.atr_v3
# 181.atr_v1
# 161.atr_v4
# 8.atr_v3
# 155.atr_ii
# 20.atr_ii
# 139.atr_v6
# 158.atr_v1
# 18.atr_avr
# 147.dat
# 121.atr_v2
# 193.atr_avr
# 12.atr_iii
# 131.atr_v6
# 165.atr_avl
# 198.atr_v4
# 105.atr_i
# 136.atr_avf
# 107.atr_iii
# 38.hea
# 139.atr_v3
# 199.atr_avl
# 175.atr_avr
# 111.atr_v4
# 76.atr_v1
# 180.atr_i
# 118.atr_v3
# 177.atr_v2
# 150.atr_v4
# 127.atr_v3
# 113.atr_avr
# 188.atr_v5
# 106.atr_i
# 63.atr_v1
# 107.atr_v3
# 191.atr_avf
# 176.atr_avr
# 197.atr_v5
# 67.atr_v5
# 110.atr_v2
# 74.atr_i
# 135.atr_v6
# 137.dat
# 186.atr_v4
# 26.atr_iii
# 45.atr_v5
# 137.atr_v6
# LICENSE.txt
# 74.atr_v6
# 108.atr_iii
# 140.atr_avf
# 12.hea
# 102.atr_v5
# 19.hea
# 152.hea
# 35.atr_avf
# 35.dat
# 45.atr_ii
# 53.atr_v6
# 170.atr_avf
# 38.atr_avl
# 156.atr_iii
# 166.atr_iii
# 135.atr_v5
# 37.atr_avl
# 120.atr_v2
# 146.atr_avf
# 52.atr_v3
# 116.atr_i
# 5.dat
# 197.atr_v2
# 130.dat
# 151.atr_v6
# 17.atr_avl
# 167.atr_v1
# 134.hea
# 16.atr_v3
# 7.atr_ii
# 35.atr_v4
# 164.dat
# 31.atr_avr
# 172.hea
# 101.atr_v4
# 141.atr_v6
# 107.atr_v2
# 193.atr_v6
# 101.atr_avl
# 112.atr_v4
# 55.atr_ii
# 151.atr_avl
# 52.atr_v6
# 41.atr_v5
# 162.atr_v5
# 179.atr_v6
# 110.atr_v5
# 160.hea
# 98.atr_avf
# 58.atr_avl
# 173.atr_iii
# 26.atr_v4
# 173.atr_v4
# 46.atr_iii
# 85.atr_v1
# 61.atr_avf
# 18.atr_v2
# 25.atr_avr
# 184.atr_v5
# 173.atr_v5
# 182.dat
# 153.atr_avr
# 121.atr_iii
# 56.atr_i
# 17.atr_iii
# 187.atr_avl
# 113.dat
# 193.atr_i
# 104.atr_v6
# 69.hea
# 115.atr_i
# 121.atr_avr
# 133.dat
# 134.atr_avf
# 54.atr_v2
# 54.atr_v4
# 75.hea
# 117.atr_avl
# 156.atr_avr
# 23.hea
# 134.atr_i
# 17.atr_v2
# 2.atr_v3
# 76.atr_avr
# 37.atr_avr
# 40.atr_v1
# 1.atr_avl
# 183.atr_iii
# 134.atr_avl
# 124.atr_v3
# 163.atr_v2
# 168.atr_iii
# 103.atr_avf
# 16.atr_i
# 139.atr_avf
# 45.atr_avr
# 174.atr_v3
# 52.atr_avl
# 27.atr_v2
# 35.atr_ii
# 92.atr_iii
# 66.atr_avl
# 1.dat
# 95.atr_avl
# 15.atr_v5
# 40.atr_i
# 128.atr_i
# 16.atr_avr
# 100.dat
# 36.atr_i
# 21.atr_v6
# 103.hea
# 48.atr_v1
# 169.atr_v1
# 188.atr_v2
# 73.dat
# 26.hea
# 150.atr_avf
# 27.atr_v6
# 188.atr_i
# 141.atr_iii
# 86.atr_i
# 170.dat
# 185.atr_avr
# 111.atr_v6
# 19.atr_iii
# 34.atr_avr
# 98.atr_v5
# 161.atr_v1
# 22.atr_v6
# 194.atr_avl
# 3.atr_v4
# 143.atr_v2
# 9.atr_v3
# 105.atr_v4
# 150.dat
# 128.atr_v4
# 63.dat
# 74.atr_v5
# 11.atr_iii
# 158.atr_avr
# 81.atr_iii
# ANNOTATORS
# 75.atr_v3
# 171.atr_ii
# 43.hea
# 9.atr_i
# 148.atr_avr
# 54.atr_avf
# 164.atr_v5
# 3.atr_v6
# 79.atr_ii
# 53.hea
# 26.atr_v1
# 74.atr_avr
# 23.atr_avr
# 175.atr_v1
# 162.atr_avf
# 33.atr_v4
# 162.atr_i
# 181.atr_avr
# 122.atr_iii
# 69.atr_ii
# 104.atr_v3
# 88.atr_iii
# 152.atr_i
# 108.atr_v2
# 29.atr_v2
# 76.hea
# 89.atr_avf
# 73.atr_v3
# 3.hea
# 116.atr_v1
# 120.atr_iii
# 165.atr_v6
# 121.atr_avf
# 122.atr_i
# 143.atr_v6
# 20.dat
# 66.atr_ii
# 178.atr_i
# 198.atr_avf
# 198.atr_v2
# 158.atr_avl
# 173.atr_v1
# 25.atr_v4
# 152.atr_v3
# 86.hea
# 60.atr_v6
# 135.hea
# 95.hea
# 34.atr_avl
# 165.atr_avf
# 11.atr_avf
# 49.atr_v5
# 189.atr_v5
# 135.atr_avr
# 134.atr_iii
# 16.hea
# 129.atr_ii
# 29.atr_v5
# 141.hea
# 111.atr_i
# 3.atr_iii
# 50.dat
# 183.hea
# 44.atr_v3
# 25.atr_ii
# 105.atr_avl
# 99.atr_v6
# 121.atr_ii
# 23.atr_v2
# 123.atr_i
# 173.atr_v6
# 187.atr_avr
# 156.atr_v1
# 173.hea
# 138.atr_v6
# 161.atr_v6
# 48.atr_avl
# 156.dat
# 149.atr_avl
# 8.atr_avl
# 42.atr_avl
# 156.atr_avf
# 19.dat
# 107.atr_avf
# 9.atr_v5
# 186.atr_v2
# 17.atr_v1
# 120.hea
# 45.dat
# 73.atr_avr
# 43.atr_v1
# 114.atr_v6
# 39.atr_v5
# 5.atr_avf
# 39.atr_iii
# 114.atr_avr
# 1.atr_i
# 21.atr_v2
# 143.atr_i
# 123.atr_ii
# 55.atr_v5
# 58.atr_v6
# 35.hea
# 48.atr_ii
# 47.atr_v4
# 30.atr_v1
# 98.atr_v1
# 48.hea
# 193.atr_v1
# 165.atr_v3
# 149.atr_avf
# 172.atr_avr
# 121.atr_avl
# 62.atr_ii
# 55.atr_avl
# 34.atr_v4
# 197.atr_i
# 79.atr_v4
# 199.atr_avf
# 18.hea
# 78.atr_avl
# 151.atr_v2
# 64.atr_ii
# 33.atr_v5
# 55.atr_v2
# 160.atr_v2
# 6.atr_v3
# 57.atr_v6
# 85.dat
# 55.atr_avf
# 50.atr_v1
# 156.atr_v5
# 29.dat
# 30.atr_ii
# 132.atr_v2
# 107.atr_v6
# 114.atr_v1
# 165.atr_v5
# 90.atr_v4
# 163.dat
# 42.atr_v1
# 22.atr_v4
# 101.atr_v3
# 23.atr_avl
# 61.atr_v6
# 61.dat
# 153.atr_v5
# 175.atr_iii
# 144.atr_iii
# 187.hea
# 128.atr_v6
# 81.atr_v5
# 184.atr_i
# 126.atr_avf
# 131.hea
# 101.hea
# 88.atr_v4
# 78.atr_ii
# 157.atr_avr
# 88.atr_v6
# 102.dat
# 12.atr_avr
# 119.atr_v4
# 46.atr_avl
# 3.atr_avf
# 11.atr_avl
# 60.atr_v2
# 175.atr_v5
# 131.atr_ii
# 108.dat
# 99.atr_i
# 196.atr_avr
# 179.atr_v4
# 53.atr_avf
# 49.hea
# 118.dat
# 9.atr_v6
# 16.atr_v5
# 169.dat
# 32.atr_v4
# 117.atr_ii
# 186.atr_v1
# 128.hea
# 101.atr_iii
# 192.atr_v2
# 119.atr_v1
# 134.atr_v5
# 190.atr_avr
# 112.atr_avf
# 48.atr_v4
# 89.hea
# 85.atr_avf
# 54.atr_v1
# 11.atr_i
# 46.dat
# 178.atr_avf
# 79.atr_i
# 47.atr_avl
# 23.atr_v4
# 82.atr_iii
# 157.atr_i
# 57.atr_avr
# 123.atr_avl
# 52.dat
# 157.atr_v5
# 4.atr_v4
# 155.atr_avr
# 51.atr_v6
# 179.atr_i
# 108.atr_avl
# 130.atr_v5
# 123.atr_avf
# 152.atr_v6
# 117.atr_v4
# 85.atr_v6
# 90.atr_v6
# 6.atr_v4
# 22.atr_i
# 159.atr_iii
# 40.atr_iii
# 104.atr_v4
# 150.atr_v2
# 137.atr_avf
# 112.atr_iii
# 107.atr_v1
# 128.atr_avf
# 82.atr_v2
# 98.atr_iii
# 61.hea
# 33.atr_ii
# 83.atr_v3
# 196.atr_v5
# 81.atr_avl
# 158.dat
# 48.atr_iii
# 200.atr_avr
# 14.atr_v6
# 73.atr_v6
# 170.atr_v2
# 76.atr_i
# 192.atr_v3
# 120.dat
# 39.atr_v4
# 185.atr_v1
# 24.atr_v6
# 35.atr_v1
# 167.hea
# 152.atr_v1
# 176.hea
# 49.atr_v3
# 130.atr_v4
# 79.atr_v5
# 190.hea
# 122.atr_avl
# 90.dat
# 73.atr_v5
# 95.atr_v5
# 83.dat
# 103.atr_avr
# 122.atr_v2
# 105.atr_v2
# 189.dat
# 96.atr_v5
# 72.atr_iii
# 10.atr_v2
# 113.hea
# 28.atr_v5
# 55.hea
# 51.hea
# 102.atr_v6
# 120.atr_v1
# 96.atr_v3
# 148.atr_avl
# 129.atr_v5
# 137.atr_v4
# 86.atr_v4
# 174.atr_v2
# 98.hea
# 86.atr_v6
# 100.atr_avl
# 65.atr_v1
# 105.atr_v1
# 172.atr_avl
# 160.atr_avl
# 130.atr_ii
# 195.atr_v6
# 47.atr_i
# 64.dat
# 36.atr_avr
# 194.atr_iii
# 82.atr_v4
# 109.atr_iii
# 41.atr_iii
# 13.atr_i
# 172.atr_v4
# 20.atr_i
# 10.atr_v6
# 117.atr_iii
# 25.atr_v2
# 173.atr_avf
# 45.atr_v2
# 143.atr_v5
# 72.atr_avf
# 84.atr_v5
# 127.atr_avf
# 98.dat
# 167.atr_v4
# 149.dat
# 161.atr_iii
# 133.atr_avl
# 168.hea
# 164.atr_v4
# 194.atr_v1
# 170.atr_ii
# 78.atr_v2
# 130.atr_v2
# 56.atr_avf
# 195.atr_avf
# 47.atr_v1
# 58.atr_ii
# 84.atr_avl
# 92.dat
# 88.atr_i
# 146.atr_v6
# 150.atr_v6
# 26.atr_v5
# 4.dat
# 124.atr_ii
# 164.atr_v1
# 58.atr_v2
# 152.atr_v5
# 140.atr_iii
# 34.hea
# 67.atr_v4
# 67.hea
# 69.atr_v1
# 65.dat
# 111.dat
# 21.atr_v1
# 41.atr_i
# 167.atr_avr
# 140.atr_v3
# 75.atr_v6
# 93.atr_v4
# 25.atr_v6
# 71.atr_v2
# 95.atr_avf
# 118.atr_v2
# 16.atr_v1
# 191.atr_v3
# 115.atr_v4
# 6.atr_v6
# 156.atr_avl
# 23.dat
# 19.atr_i
# 41.atr_ii
# 193.atr_iii
# 138.atr_ii
# 66.atr_v4
# 28.atr_v3
# 127.atr_i
# 168.atr_avr
# 62.atr_v3
# 74.atr_v4
# 163.hea
# 84.atr_avf
# 147.atr_avl
# 51.atr_v4
# 154.atr_v6
# 53.atr_iii
# 159.atr_avr
# 123.dat
# 7.atr_avl
# 179.atr_avr
# 176.atr_v3
# 87.atr_avr
# 172.atr_avf
# 107.atr_i
# 31.atr_i
# 153.atr_v1
# 82.atr_v1
# 186.hea
# 13.hea
# 132.atr_v6
# 161.atr_v2
# 136.dat
# 175.atr_i
# 11.hea
# 133.atr_v5
# 10.atr_avr
# 4.atr_v3
# 178.atr_avr
# 136.hea
# 126.atr_v6
# 151.atr_avr
# 147.hea
# 183.atr_avf
# 150.atr_i
# 83.atr_v5
# 37.atr_v2
# 122.atr_v3
# 69.atr_iii
# 109.atr_v5
# 164.atr_iii
# 5.atr_v4
# 19.atr_v3
# 132.atr_iii
# 118.atr_v6
# 134.dat
# 83.atr_avl
# 150.atr_avl
# 36.atr_iii
# 133.atr_v3
# 45.atr_v1
# 97.atr_v3
# 47.atr_v3
# 114.atr_v2
# 39.atr_avr
# 67.atr_v1
# 126.atr_v5
# 150.atr_v3
# 90.atr_ii
# 40.hea
# 93.atr_v2
# 14.atr_avf
# 188.atr_v4
# 173.atr_v3
# 126.atr_iii
# 169.atr_avr
# 7.atr_v5
# 44.hea
# 75.atr_ii
# 38.atr_v3
# 110.atr_iii
# 194.atr_v2
# 135.atr_v1
# 128.atr_v3
# 191.atr_v5
# 94.atr_avr
# 80.atr_avl
# 85.atr_ii
# 189.hea
# 151.atr_ii
# 60.atr_iii
# 71.atr_ii
# 98.atr_ii
# 175.atr_v3
# 17.atr_v3
# 196.atr_v1
# 109.atr_v3
# 161.atr_v3
# 163.atr_i
# 53.atr_ii
# 159.atr_v4
# 181.atr_avf
# 174.atr_v1
# 17.atr_avf
# 83.atr_iii
# 30.atr_v6
# 157.atr_v4
# 45.hea
# 44.atr_v5
# 98.atr_v6
# 76.dat
# 51.dat
# 108.atr_v5
# 10.atr_iii
# 9.atr_v4
# 132.atr_v3
# 110.atr_avl
# 46.atr_v6
# 48.atr_v6
# 57.dat
# 159.atr_avl
# 155.dat
# 92.atr_avr
# 192.atr_ii
# 28.atr_iii
# 31.atr_v6
# 56.atr_v1
# 135.atr_ii
# 70.atr_ii
# 112.atr_i
# 158.atr_avf
# 192.hea
# 28.hea
# 141.atr_v4
# 58.atr_v4
# 198.atr_v6
# 191.dat
# 128.atr_v5
# README
# 106.atr_v2
# 87.atr_v6
# 180.atr_v2
# 184.atr_v1
# 66.atr_v3
# 85.atr_v5
# 162.atr_iii
# 182.hea
# 145.atr_v4
# 100.atr_v3
# 77.atr_v4
# 107.atr_ii
# 51.atr_i
# 131.atr_v4
# 94.atr_v1
# 19.atr_avr
# 81.atr_v2
# 33.atr_avf
# 12.atr_ii
# 67.atr_avl
# 180.atr_avf
# 143.atr_avf
# 41.atr_avr
# 168.atr_v1
# 78.dat
# 63.atr_avl
# 88.atr_v3
# 148.atr_v6
# 29.atr_v3
# 55.dat
# 125.atr_v2
# 182.atr_v1
# 135.atr_iii
# 37.atr_i
# 58.atr_v5
# 134.atr_v1
# 56.atr_v3
# 7.atr_v4
# 179.atr_v3
# 179.atr_v1
# 124.dat
# 169.atr_v3
# 126.atr_v2
# 186.dat
# 30.atr_v3
# 102.atr_v1
# 90.atr_avl
# 7.atr_i
# 80.atr_ii
# 101.atr_v6
# 108.atr_avf
# 69.atr_v3
# 36.atr_v4
# 41.atr_avl
# 145.atr_v3
# 109.atr_avf
# 155.atr_i
# 36.atr_v3
# 100.atr_v5
# 88.atr_avl
# 48.atr_avf
# 93.atr_avl
# 190.atr_v2
# 125.atr_avr
# 67.atr_avf
# 25.atr_v1
# 104.atr_v2
# 193.atr_ii
# 187.atr_i
# 50.atr_i
# 134.atr_ii
# 140.atr_avl
# 130.hea
# 15.atr_v2
# 187.atr_avf
# 124.atr_iii
# 97.atr_avf
# 67.atr_v3
# 1.atr_v6
# 43.atr_avf
# 161.dat
# 137.atr_v1
# 180.atr_avl
# 95.atr_iii
# 90.atr_avf
# 120.atr_i
# 23.atr_v3
# 1.atr_v4
# 70.atr_avf
# 144.atr_i
# 64.atr_v1
# 97.atr_v4
# 139.atr_v1
# 77.atr_v3
# 140.hea
# 112.atr_v6
# 117.atr_v2
# 44.atr_avr
# 186.atr_avl
# 82.atr_avf
# 144.atr_v5
# 90.atr_iii
# 13.atr_v1
# 120.atr_v4
# 142.atr_avf
# 43.atr_v4
# 159.atr_v1
# 23.atr_avf
# 145.atr_i
# 32.atr_i
# 118.atr_v5
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-23-75efdec16fa5> in <module>()
#       4 record_list = pd.read_csv(os.path.join(folder_path,'RECORDS')).values.ravel()
#       5
# ----> 6 xxt,yyt=LoaddDatFiles(file_list[ :round(len(file_list)*perct) ]) # training data.
#       7 xxt,yyt=unison_shuffled_copies(xxt,yyt) ### shuffle
#       8 xxv,yyv=LoaddDatFiles(file_list[ -round(len(file_list)*percv): ] ) ## validation data.
#
# <ipython-input-10-50f58fa275d5> in LoaddDatFiles(datfiles)
#      20                         xx = x
#      21                         yy = y
# ---> 22         return(xx,yy)
#
# UnboundLocalError: local variable 'xx' referenced before assignment

# %%
# call keras/tensorflow and build lstm model

## ORIGINAL KTF.set_session(get_session())
tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction)
tf.compat.v1.keras.backend.set_session(get_session())

with tf.device('/cpu:0'): #switch to /cpu:0 to use cpu 
	if not os.path.isfile('model.h5'):
		model = getmodel() # build model
		model.fit(xxt, yyt, batch_size=32, epochs=100, verbose=1) # train the model
		model.save('model.h5')

	model = load_model('model.h5')
	score, acc = model.evaluate(xxv, yyv, batch_size=4, verbose=1)
	print('Test score: {} , Test accuracy: {}'.format(score, acc))
	
	# predict
	yy_predicted = model.predict(xxv) 

	# maximize probabilities of prediction.
	for i in range(yyv.shape[0]): 
		b = np.zeros_like(yy_predicted[i,:,:])
		b[np.arange(len(yy_predicted[i,:,:])), yy_predicted[i,:,:].argmax(1)] = 1
		yy_predicted[i,:,:] = b

	# plot: 
	with PdfPages('ecg.pdf') as pdf:
		for i in range( xxv.shape[0] ): 
			print (i)
			plotecg_validation(xxv[i,:,:],yy_predicted[i,:,:],yyv[i,:,:],0,yy_predicted.shape[1])  # top = predicted, bottom=true
			pdf.savefig()
			plt.close()

	#plotecg(xv[1,:,:],yv[1,:,:],0,yv.shape[1]) ## plot first seq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8e5dca859f25> in <module>()
#       2
#       3 ## ORIGINAL KTF.set_session(get_session())
# ----> 4 tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction)
#       5 tf.compat.v1.keras.backend.set_session(get_session())
#       6
#
# NameError: name 'per_process_gpu_memory_fraction' is not defined
